# %%
# !pip install textblob
# !python -m textblob.download_corpora
# Out:
# Requirement already satisfied: textblob in c:\users\mepz\anaconda3\lib\site-packages (0.19.0)
# Requirement already satisfied: nltk>=3.9 in c:\users\mepz\anaconda3\lib\site-packages (from textblob) (3.9.2)
# Requirement already satisfied: click in c:\users\mepz\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (8.2.1)
# Requirement already satisfied: joblib in c:\users\mepz\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\mepz\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (2025.9.1)
# Requirement already satisfied: tqdm in c:\users\mepz\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (4.67.1)
# Requirement already satisfied: colorama in c:\users\mepz\anaconda3\lib\site-packages (from click->nltk>=3.9->textblob) (0.4.6)
# Finished.
# [nltk_data] Downloading package brown to
# [nltk_data]     C:\Users\MEPZ\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\brown.zip.
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\MEPZ\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\MEPZ\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\MEPZ\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger_eng.zip.
# [nltk_data] Downloading package conll2000 to
# [nltk_data]     C:\Users\MEPZ\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\conll2000.zip.
# [nltk_data] Downloading package movie_reviews to
# [nltk_data]     C:\Users\MEPZ\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\movie_reviews.zip.

# %%
from textblob.classifiers import NaiveBayesClassifier
train = [('Air India did a poor job of queue management both times.','staff service'),
         ("The 'cleaning' by flight attendants involved regularly spraying air freshener in the lavatories.", 'staff'),
         ('The food tasted decent.','food'),
         ('Flew Air India direct from New York to Delhi round trip.', 'route'),
         ('Colombo to Moscow via Delhi.','route'),
         ('Flew Birmingham to Delhi with Air India.','route'), 
         ('Without toilet, food or anything!', 'food'),
         ('Cabin crew announcements included a sincere apology for the delay.','cabin flown')]

cl = NaiveBayesClassifier(train)
tests = ['Food is good.']
test1 = ['Travelled from Chennai to Singapore with a short layover.']
for c in tests:
  print(cl.classify(c))
for i in test1:
    print(cl.classify(i))
# Out:
# food
# route

# %%
train = [('I love this sandwich.', 'pos'), 
         ('this is an amazing place!', 'pos'),
         ('I feel very good about these beers.', 'pos'),
         ('this is my best work.', 'pos'),
         ("what an awesome view", 'pos'),
         ('I do not like this restaurant','neg'),
         ('I am tired of this stuff.', 'neg'),
         ("I can't deal with this", 'neg'),
         ('he is my sworn enemy!', 'neg'),
         ('my boss is horrible.', 'neg')]

cl = NaiveBayesClassifier(train)

print(cl.classify("This is an amazing library!"))
print(cl.classify("I can't do this!"))
# Out:
# pos
# neg

# %%
sen = "I don't like myself"
sen2 = "I am tired of the work"
sen3 = "I like cookies"
print(cl.classify(sen))
print(cl.classify(sen2))
print(cl.classify(sen3))
# Out:
# neg
# neg
# neg
